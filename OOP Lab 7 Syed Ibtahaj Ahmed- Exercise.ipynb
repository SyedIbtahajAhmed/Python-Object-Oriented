# %% [markdown]
# ## Object Oriented Programming Lab - 7
#
# ## Composition
#
#
# ### Student Name:  SYED IBTAHAJ AHMED RIZVI
# ### Student Id:  FA18 - BECE - 0016
#
# ### Objective
#
# To understand the concepts of Cmoposition in OOP using Python.

# %% [markdown]
# 1- Mohammad Ali Jinnah University purchases Multiple robots to perform 02 major operations for the students and faculty. For example: 'Cleanobot' performs cleaning of the doorways and corridors of the university. 'Secubot' is an automated robot that stops students from entering the university without their ID cards. Think of more robots that might perform different duties. Using concepts of Composition, create a Generic Robot class with attributes of your own choice. Create another class Department. Create different types of robot instances within this class that use the Robot class attributes. Presnet your output in a readable format where it shows the functionality of a particular robot and to which department it might belong.

# %%
class InvalidRobot(Exception):
    pass
class Robot:
    def __init__(self, name = None):
        self.name = name
    def Cleanobot(self):
        return "Performs Cleaning Of The Doorways and Corridors Of The University!"
    def Secubot(self):
        return "is an automated robot that stops students from entering the university without their ID Cards."
class Department:
    def __init__(self, name = None, depart = None):
        self.depart = None
        self.rob = Robot(name)
    def take_inputs(self):
        self.depart = str(input("Enter Department: "))
        self.rob.name = str(input("Enter Robot Name: "))
    def Display(self):
        try:
            if(self.rob.name == "Cleanobot" or self.rob.name == "cleanobot"):
                print("\n\n{} {}".format(self.rob.name, self.rob.Cleanobot()))
                print("\nIt belongs to : {} department.".format(self.depart))
            elif(self.rob.name == "Secubot" or self.rob.name == "secubot"):
                print("\n\n{} {}".format(self.rob.name, self.rob.Secubot()))
                print("\nIt belongs to : {} department.".format(self.depart))
            else:
                raise InvalidRobot
        except(InvalidRobot):
            print("The Robot You Entered Is Not Valid Or Spelled Incorrect.")
        finally:
            print("Thanks For Using!")

anykey = str(input("Press Any Key To Continue or Q To Quit: "))
while(anykey != 'q'):
    obj = Department()
    obj.take_inputs()
    obj.Display()
    anykey = str(input("Press Any Key To Continue or Q To Quit: "))

# %% [markdown]
# 2- Refer to Lab Manual 3 Question 3. Implement the Vehicle Classes using Composition. Compare how Composition code efficiency to inheritance approach.

# %%
class Vehicle:
    def __init__(self, color = None, seats = None, mile = None, sound = None):
        self.color = color
        self.seats = seats
        self.mile = mile
        self.sound = sound
class Bike:
    def __init__(self, color = None, seats = None, mile = None, sound = None):
        self.obj = Vehicle(color, seats, mile, sound)
        self.obj.sound = sound
    def inputs(self):
        self.obj.color = str(input("Please Enter Color Of Bike:"))
        self.obj.seats = str(input("Please Enter Seating Capacity Of Bike:"))
        self.obj.mile = str(input("Please Enter Mileage Of Bike:"))
    def printing(self):
        print("\n\nThe Color Of The Bike Is : ", self.obj.color)
        print("The Seating Capacity Of The Bike Is : ", self.obj.seats)
        print("The Mileage Of The Bike Is : ", self.obj.mile)
    def sound_veh(self):
        self.obj.sound = "BRRRR BRRR BRRR BRRRR!"
        return self.obj.sound
class Car:
    def __init__(self, color = None, seats = None, mile = None, sound = None):
        self.obj = Vehicle(color, seats, mile, sound)
        self.obj.sound = sound
    def inputs(self):
        self.obj.color = str(input("Please Enter Color Of Car:"))
        self.obj.seats = str(input("Please Enter Seating Capacity Of Car:"))
        self.obj.mile = str(input("Please Enter Mileage Of Car:"))
    def printing(self):
        print("\n\nThe Color Of The Car Is : ", self.obj.color)
        print("The Seating Capacity Of The Car Is : ", self.obj.seats)
        print("The Mileage Of The Car Is : ", self.obj.mile)
    def sound_veh(self):
        self.obj.sound = "WROOM WROOM WROOM WROOM WROOM!"
        return self.obj.sound 
class Truck:
    def __init__(self, color = None, seats = None, mile = None, sound = None):
        self.obj = Vehicle(color, seats, mile, sound)
        self.obj.sound = sound
    def inputs(self):
        self.obj.color = str(input("Please Enter Color Of Truck:"))
        self.obj.seats = str(input("Please Enter Seating Capacity Of Truck:"))
        self.obj.mile = str(input("Please Enter Mileage Of Truck:"))
    def printing(self):
        print("\n\nThe Color Of The Truck Is : ", self.obj.color)
        print("The Seating Capacity Of The Truck Is : ", self.obj.seats)
        print("The Mileage Of The Truck Is : ", self.obj.mile)
    def sound_veh(self):
        self.obj.sound = "TRRRR TRRRR TRRRR TRRRR TRRRR!"
        return self.obj.sound
obj1 = Bike()
obj1.inputs()
obj1.printing()
print(obj1.sound_veh())
obj2 = Car()
obj2.inputs()
obj2.printing()
print(obj2.sound_veh())
obj3 = Truck()
obj3.inputs()
obj3.printing()
print(obj3.sound_veh())

# %% [markdown]
# 3- Refer to Lab Manual 3 Question 4. Implement the same objective using Composition.

# %%
class Players:
    def __init__(self, name = [], age = [], categ = [], captain = None):
        self.name = name
        self.age = age
        self.categ = categ
        self.captain = captain
        
    def name_inputs(self):
        for i in range(1,12):
            self.name.append(input("Enter Name Of The {} Player Of Playing Eleven:".format(i)))
    def age_inputs(self):
        for i in range(0,11):
            self.age.append(input("Enter Age Of {} :".format(self.name[i])))
    def print_eleven(self):
        print("\n\nTHE PLAYING ELEVEN")
        for i in range(0,11):
            if(self.captain == i):
                print("\nName Of The Player Is: ", self.name[i], "(Captain)")
                print("Age Of The Player Is: ", self.age[i])
                print("He Is A: ", self.categ[i])

            else:
                print("\nName Of The Player Is: ", self.name[i])
                print("Age Of The Player Is: ", self.age[i])
                print("He Is A: ", self.categ[i])

class Category:
    def __init__(self, name = [], age = [], categ = []):
        self.obj = Players(name, age, categ)
    
    def categ_inputs(self):
        for i in range(0, 11):
            print("\nIn What Category You Want {} In :".format(self.obj.name[i]))
            print("Press 1 For Batsman")
            print("Press 2 For Bowler")
            print("Press 3 For Wicket Keeper")
            print("Press 4 For All Rounder")
            cat = int(input())
            if(cat == 1):
                self.obj.categ.append("Batsman")
            elif(cat == 2):
                self.obj.categ.append("Bowler")
            elif(cat == 3):
                self.obj.categ.append("Wicket Keeper")
            elif(cat == 4):
                self.obj.categ.append("All Rounder")
            else:
                print("\nÏnvalid Input!Please Try Again.")
                print("\nIn What Category You Want {} In :".format(self.obj.name[i]))
                print("Press 1 For Batsman")
                print("Press 2 For Bowler")
                print("Press 3 For Wicket Keeper")
                print("Press 4 For All Rounder")
                cat = str(input())
    def choose_captain(self):
        print("From The Given Eleven Who Do You Want To Declare The Captain")
        print("Press The Number To Make Him Captain")
        for i in range(0,11):
            print(i , self.obj.name[i])
        self.obj.captain = int(input())
        
team1 = Category()
team1.obj.name_inputs()
print("\n")
team1.obj.age_inputs()
team1.categ_inputs()
team1.choose_captain()
team1.obj.print_eleven()
